# %%
import keras
import random, os
from keras.layers import *
from keras.models import Model, Sequential
from keras import backend as K
from glob import glob
import numpy as np
import re
from keras.utils.vis_utils import model_to_dot
import random
import matplotlib.pyplot as plt
from scipy.spatial import distance
from IPython.display import Image
import PIL
# Out:
# Using TensorFlow backend.

# %%
batch_size = 256
num_classes = 6
epochs = 1000
img_rows, img_cols = 28, 28
label = ["circle", "square", "triangle", "horizontal", "vertical", "diagonal"]

# %%
def load_data():
    tr_path = './dataset/trains/'
    te_path = './dataset/tests/'
    va_path = './dataset/vals/'
    
    (tr_sets, tr_labels, _) = get_datasets_labels(tr_path)
    (te_sets, te_labels, test_labels_with_num) = get_datasets_labels(te_path)
    (va_sets, va_labels, _) = get_datasets_labels(va_path)
    
    tr_sets = np.array(tr_sets)
    te_sets = np.array(te_sets)
    va_sets = np.array(va_sets)
    tr_labels = np.array(tr_labels)
    te_labels = np.array(te_labels)
    va_labels = np.array(va_labels)
    test_labels_with_num = np.array(test_labels_with_num)
    return tr_sets, tr_labels, te_sets, te_labels, va_sets, va_labels, test_labels_with_num

# %%
def get_datasets_labels(path):
	files = os.listdir(path)
	labels = []
	lbs = []
	sets = []
	for file in files:
		pic = PIL.Image.open(path + file).convert('L')
		lb = file.replace(re.findall("\d+", file)[0], '').replace('.png', '') 
		forlb = file.replace('.png', '') 
		
		labels.append(label.index(lb))
		lbs.append(forlb)
		
		pic = np.array(pic)
		sets.append(pic)
	return sets, labels, lbs

# %%
(x_train, y_train, x_test, y_test, x_val, y_val, test_labels_with_num) = load_data()
y_test1 = y_test
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
y_val = keras.utils.to_categorical(y_val, num_classes)
input_shape = (img_rows, img_cols, 1)

x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
x_val = x_val.reshape(x_val.shape[0], img_rows, img_cols, 1)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_val = x_val.astype('float32')
x_train /= 255.
x_test /= 255.
x_val /= 255.

# %%
model = Sequential()
model.add(Conv2D(128, (3, 3), padding='same', input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D((2, 2), padding='same'))

model.add(Conv2D(128, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D((2, 2), padding='same'))
#model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D((2, 2), padding='same'))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D((2, 2), padding='same'))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(64, activation = 'relu'))

#model.add(Dropout(0.25))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 128)       1280
# _________________________________________________________________
# activation_1 (Activation)    (None, 28, 28, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 128)       147584
# _________________________________________________________________
# activation_2 (Activation)    (None, 14, 14, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 64)          73792
# _________________________________________________________________
# activation_3 (Activation)    (None, 7, 7, 64)          0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 4, 4, 64)          0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 390
# _________________________________________________________________
# activation_5 (Activation)    (None, 6)                 0
# =================================================================
# Total params: 301,126
# Trainable params: 301,126
# Non-trainable params: 0
# _________________________________________________________________

# %%
num = 1
for layer in model.layers:
    print(num, layer, layer.trainable)
    num = num+1
# Out:
# 1 <keras.layers.convolutional.Conv2D object at 0x7f86364f2978> True
# 2 <keras.layers.core.Activation object at 0x7f86364f2b38> True
# 3 <keras.layers.pooling.MaxPooling2D object at 0x7f86364f2e48> True
# 4 <keras.layers.convolutional.Conv2D object at 0x7f86364f2eb8> True
# 5 <keras.layers.core.Activation object at 0x7f8636226e48> True
# 6 <keras.layers.pooling.MaxPooling2D object at 0x7f86361e39e8> True
# 7 <keras.layers.convolutional.Conv2D object at 0x7f86361e3978> True
# 8 <keras.layers.core.Activation object at 0x7f8636158358> True
# 9 <keras.layers.pooling.MaxPooling2D object at 0x7f86361587f0> True
# 10 <keras.layers.convolutional.Conv2D object at 0x7f86360ed3c8> True
# 11 <keras.layers.core.Activation object at 0x7f86360ed4a8> True
# 12 <keras.layers.pooling.MaxPooling2D object at 0x7f8636107a58> True
# 13 <keras.layers.core.Flatten object at 0x7f8636107978> True
# 14 <keras.layers.core.Dense object at 0x7f8636169a90> True
# 15 <keras.layers.core.Dropout object at 0x7f86361692e8> True
# 16 <keras.layers.core.Dense object at 0x7f8636181898> True
# 17 <keras.layers.core.Dense object at 0x7f86361819b0> True
# 18 <keras.layers.core.Activation object at 0x7f86361a2320> True

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=0, validation_data=(x_val, y_val))

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.06914143885962555
# Test accuracy: 0.9883333333333333

# %%
model_json = model.to_json()
with open("origin_cnn_model.json", "w") as json_file : 
    json_file.write(model_json)

# %%
model.save_weights("origin_cnn_model.h5")
print("saved model to disk")
# Out:
# saved model to disk

# %%
for layer in model.layers:
    layer.trainable = False

# %%
for i in range(6):
    model.pop()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 128)       1280
# _________________________________________________________________
# activation_1 (Activation)    (None, 28, 28, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 128)       147584
# _________________________________________________________________
# activation_2 (Activation)    (None, 14, 14, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 64)          73792
# _________________________________________________________________
# activation_3 (Activation)    (None, 7, 7, 64)          0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 4, 4, 64)          0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 64)          0
# =================================================================
# Total params: 560,710
# Trainable params: 301,126
# Non-trainable params: 259,584
# _________________________________________________________________
# /home/minji/.conda/envs/tensor/lib/python3.6/site-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'

# %%
model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(UpSampling2D((2, 2)))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(UpSampling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (2, 2)))
model.add(Conv2D(128, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(UpSampling2D((2, 2)))

model.add(Conv2D(128, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(UpSampling2D((2, 2)))
#model.add(Dropout(0.25))

model.add(Conv2D(1, (3, 3), padding='same'))
model.add(Activation('relu'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 128)       1280
# _________________________________________________________________
# activation_1 (Activation)    (None, 28, 28, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 128)       147584
# _________________________________________________________________
# activation_2 (Activation)    (None, 14, 14, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 64)          73792
# _________________________________________________________________
# activation_3 (Activation)    (None, 7, 7, 64)          0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 4, 4, 64)          0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 2, 2, 64)          36928
# _________________________________________________________________
# activation_6 (Activation)    (None, 2, 2, 64)          0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# activation_7 (Activation)    (None, 4, 4, 64)          0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 7, 7, 64)          16448
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 7, 7, 128)         73856
# _________________________________________________________________
# activation_8 (Activation)    (None, 7, 7, 128)         0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 14, 14, 128)       147584
# _________________________________________________________________
# activation_9 (Activation)    (None, 14, 14, 128)       0
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 28, 28, 1)         1153
# _________________________________________________________________
# activation_10 (Activation)   (None, 28, 28, 1)         0
# =================================================================
# Total params: 560,710
# Trainable params: 301,126
# Non-trainable params: 259,584
# _________________________________________________________________

# %%
num = 1
for layer in model.layers:
    print(num, layer, layer.trainable)
    num = num+1
# Out:
# 1 <keras.layers.convolutional.Conv2D object at 0x7f86364f2978> False
# 2 <keras.layers.core.Activation object at 0x7f86364f2b38> False
# 3 <keras.layers.pooling.MaxPooling2D object at 0x7f86364f2e48> False
# 4 <keras.layers.convolutional.Conv2D object at 0x7f86364f2eb8> False
# 5 <keras.layers.core.Activation object at 0x7f8636226e48> False
# 6 <keras.layers.pooling.MaxPooling2D object at 0x7f86361e39e8> False
# 7 <keras.layers.convolutional.Conv2D object at 0x7f86361e3978> False
# 8 <keras.layers.core.Activation object at 0x7f8636158358> False
# 9 <keras.layers.pooling.MaxPooling2D object at 0x7f86361587f0> False
# 10 <keras.layers.convolutional.Conv2D object at 0x7f86360ed3c8> False
# 11 <keras.layers.core.Activation object at 0x7f86360ed4a8> False
# 12 <keras.layers.pooling.MaxPooling2D object at 0x7f8636107a58> False
# 13 <keras.layers.convolutional.Conv2D object at 0x7f862c762fd0> True
# 14 <keras.layers.core.Activation object at 0x7f862c762f98> True
# 15 <keras.layers.convolutional.UpSampling2D object at 0x7f862c7ac278> True
# 16 <keras.layers.convolutional.Conv2D object at 0x7f862c7ac898> True
# 17 <keras.layers.core.Activation object at 0x7f862c7ac198> True
# 18 <keras.layers.convolutional.UpSampling2D object at 0x7f862c768978> True
# 19 <keras.layers.core.Dropout object at 0x7f862c768b38> True
# 20 <keras.layers.convolutional.Conv2D object at 0x7f862c768c88> True
# 21 <keras.layers.convolutional.Conv2D object at 0x7f862c768d68> True
# 22 <keras.layers.core.Activation object at 0x7f862c7296d8> True
# 23 <keras.layers.convolutional.UpSampling2D object at 0x7f862c67b6a0> True
# 24 <keras.layers.convolutional.Conv2D object at 0x7f862c67b748> True
# 25 <keras.layers.core.Activation object at 0x7f862c67b8d0> True
# 26 <keras.layers.convolutional.UpSampling2D object at 0x7f862c69bf60> True
# 27 <keras.layers.core.Dropout object at 0x7f862c6b77b8> True
# 28 <keras.layers.convolutional.Conv2D object at 0x7f862c6b7828> True
# 29 <keras.layers.core.Activation object at 0x7f862c6b7a58> True

# %%
model.compile(optimizer='adadelta', loss='binary_crossentropy')

# %%
model.fit(x_train, x_train,
        batch_size=batch_size,
        epochs=epochs,
        verbose=0, 
        shuffle = True,
        validation_data=(x_val, x_val))

# %%
model.evaluate(x_test, x_test, verbose = 0)
# Out:
# 0.4945578622817993

# %%
pred = model.predict(x_test)

# %%
import matplotlib.pyplot as plt

obj = -1
for j in range(len(pred)):
    f, ax = plt.subplots(1,6)
    for i in range(6):
        if i % 2 == 0:
            obj = obj + 1
            if obj >= 600:
                break
            #print(obj)
            ax[i].imshow(x_test[obj].reshape(img_rows, img_cols), cmap=plt.get_cmap('gray'))
        else:
            #print()
            ax[i].imshow(pred[obj].reshape(img_rows, img_cols), cmap=plt.get_cmap('gray'))
    if obj >= 600:
        break
    plt.show()

# %%
from keras.models import model_from_json 
json_file = open("origin_cnn_model.json", "r") 
loaded_model_json = json_file.read() 
json_file.close() 
cnn_model = model_from_json(loaded_model_json)

# %%
cnn_model.load_weights("origin_cnn_model.h5") 
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
cnn_model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

# %%
cnn_model.evaluate(x_test, y_test)
# Out:
# 1200/1200 [==============================] - 0s 148us/step
# [0.06914143885962555, 0.9883333333333333]

# %%
cnn_model.evaluate(pred, y_test)
# Out:
# 1200/1200 [==============================] - 0s 53us/step
# [1.5662028376261394, 0.7741666666666667]

# %%
'''
#TEST 1
0.10420278875487289, 0.9822222222222222
2.323088133070204, 0.7855555555555556

#TEST2
0.04724142621778242, 0.9933333333333333
1.7464376485347748, 0.81
'''
# Out:
# '\n#TEST 1\n0.10420278875487289, 0.9822222222222222\n2.323088133070204, 0.7855555555555556\n\n#TEST2\n0.04724142621778242, 0.9933333333333333\n1.7464376485347748, 0.81\n'
