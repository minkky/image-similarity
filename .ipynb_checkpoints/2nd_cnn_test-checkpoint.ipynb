# %%
import keras
import random, os
from keras.layers import Activation, Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Dropout, Flatten
from keras.models import Model, Sequential
from keras import backend as K
from glob import glob
import numpy as np
import re
from keras.utils.vis_utils import model_to_dot
import random
import matplotlib.pyplot as plt
from scipy.spatial import distance
from IPython.display import Image
import PIL
# Out:
# Using TensorFlow backend.

# %%
batch_size = 256
num_classes = 6
epochs = 1000
img_rows, img_cols = 28, 28
label = ["circle", "square", "triangle", "horizontal", "vertical", "diagonal"]

# %%
def load_data():
    tr_path = './dataset/trains/'
    te_path = './dataset/tests/'
    va_path = './dataset/vals/'
    
    (tr_sets, tr_labels, _) = get_datasets_labels(tr_path)
    (te_sets, te_labels, test_labels_with_num) = get_datasets_labels(te_path)
    (va_sets, va_labels, _) = get_datasets_labels(va_path)
    
    
    tr_sets = np.array(tr_sets)
    te_sets = np.array(te_sets)
    va_sets = np.array(va_sets)
    tr_labels = np.array(tr_labels)
    te_labels = np.array(te_labels)
    va_labels = np.array(va_labels)
    test_labels_with_num = np.array(test_labels_with_num)
    return tr_sets, tr_labels, te_sets, te_labels, va_sets, va_labels, test_labels_with_num

# %%
def get_datasets_labels(path):
	files = os.listdir(path)
	labels = []
	lbs = []
	sets = []
	for file in files:
		pic = PIL.Image.open(path + file).convert('L')
		lb = file.replace(re.findall("\d+", file)[0], '').replace('.png', '') 
		forlb = file.replace('.png', '') 
		
		labels.append(label.index(lb))
		lbs.append(forlb)
		
		pic = np.array(pic)
		sets.append(pic)
	return sets, labels, lbs

# %%
(x_train, y_train, x_test, y_test, x_val, y_val, test_labels_with_num) = load_data()
y_test1 = y_test
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
y_val = keras.utils.to_categorical(y_val, num_classes)
input_shape = (img_rows, img_cols, 1)

x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
x_val = x_val.reshape(x_val.shape[0], img_rows, img_cols, 1)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_val = x_val.astype('float32')
x_train /= 255.
x_test /= 255.
x_val /= 255.

# %%
model = Sequential()
model.add(Conv2D(128, (3, 3), padding='same', input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D((2, 2), padding='same'))

model.add(Conv2D(128, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D((2, 2), padding='same'))
#

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D((2, 2), padding='same'))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D((2, 2), padding='same'))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(64, activation = 'relu'))

#model.add(Dropout(0.25))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 128)       1280
# _________________________________________________________________
# activation_1 (Activation)    (None, 28, 28, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 128)       147584
# _________________________________________________________________
# activation_2 (Activation)    (None, 14, 14, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 64)          73792
# _________________________________________________________________
# activation_3 (Activation)    (None, 7, 7, 64)          0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 4, 4, 64)          0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 390
# =================================================================
# Total params: 301,126
# Trainable params: 301,126
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=0, validation_data=(x_val, y_val))

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))
# Out:
# Train on 2400 samples, validate on 1800 samples
# Epoch 1/1000
# 2400/2400 [==============================] - 2s 686us/step - loss: 1.7931 - acc: 0.1650 - val_loss: 1.7910 - val_acc: 0.1906
# Epoch 2/1000
# 2400/2400 [==============================] - 0s 59us/step - loss: 1.7916 - acc: 0.1771 - val_loss: 1.7919 - val_acc: 0.1839
# Epoch 3/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 1.7925 - acc: 0.1708 - val_loss: 1.7889 - val_acc: 0.1667
# Epoch 4/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 1.7900 - acc: 0.1888 - val_loss: 1.7814 - val_acc: 0.1689
# Epoch 5/1000
# 2400/2400 [==============================] - 0s 59us/step - loss: 1.7803 - acc: 0.1917 - val_loss: 1.7893 - val_acc: 0.1672
# Epoch 6/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 1.7854 - acc: 0.2033 - val_loss: 1.7482 - val_acc: 0.2717
# Epoch 7/1000
# 2400/2400 [==============================] - 0s 69us/step - loss: 1.7419 - acc: 0.2604 - val_loss: 1.8081 - val_acc: 0.1667
# Epoch 8/1000
# 2400/2400 [==============================] - 0s 74us/step - loss: 1.7738 - acc: 0.2508 - val_loss: 1.8032 - val_acc: 0.1972
# Epoch 9/1000
# 2400/2400 [==============================] - 0s 81us/step - loss: 1.7825 - acc: 0.2142 - val_loss: 1.7186 - val_acc: 0.2139
# Epoch 10/1000
# 2400/2400 [==============================] - 0s 74us/step - loss: 1.6391 - acc: 0.3317 - val_loss: 1.5773 - val_acc: 0.3433
# Epoch 11/1000
# 2400/2400 [==============================] - 0s 59us/step - loss: 1.5567 - acc: 0.3908 - val_loss: 1.6236 - val_acc: 0.3767
# Epoch 12/1000
# 2400/2400 [==============================] - 0s 75us/step - loss: 1.4810 - acc: 0.4033 - val_loss: 1.3646 - val_acc: 0.4589
# Epoch 13/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 1.3699 - acc: 0.4708 - val_loss: 1.0706 - val_acc: 0.5811
# Epoch 14/1000
# 2400/2400 [==============================] - 0s 75us/step - loss: 1.3293 - acc: 0.4754 - val_loss: 1.3873 - val_acc: 0.4478
# Epoch 15/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 1.1452 - acc: 0.5567 - val_loss: 0.9204 - val_acc: 0.6444
# Epoch 16/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 1.0901 - acc: 0.5658 - val_loss: 0.8587 - val_acc: 0.6706
# Epoch 17/1000
# 2400/2400 [==============================] - 0s 74us/step - loss: 1.0135 - acc: 0.5900 - val_loss: 1.0228 - val_acc: 0.6211
# Epoch 18/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 0.9487 - acc: 0.6300 - val_loss: 0.6484 - val_acc: 0.7544
# Epoch 19/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 0.8197 - acc: 0.6829 - val_loss: 0.9918 - val_acc: 0.5967
# Epoch 20/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 0.7759 - acc: 0.6829 - val_loss: 1.0517 - val_acc: 0.6011
# Epoch 21/1000
# 2400/2400 [==============================] - 0s 65us/step - loss: 0.7576 - acc: 0.7050 - val_loss: 0.5112 - val_acc: 0.8406
# Epoch 22/1000
# 2400/2400 [==============================] - 0s 69us/step - loss: 0.5760 - acc: 0.7696 - val_loss: 0.4295 - val_acc: 0.8556
# Epoch 23/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 0.6516 - acc: 0.7567 - val_loss: 0.4997 - val_acc: 0.8106
# Epoch 24/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 0.4691 - acc: 0.8304 - val_loss: 0.4410 - val_acc: 0.8267
# Epoch 25/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 0.5213 - acc: 0.8071 - val_loss: 0.3087 - val_acc: 0.8989
# Epoch 26/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 0.4367 - acc: 0.8362 - val_loss: 0.3681 - val_acc: 0.8778
# Epoch 27/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 0.3912 - acc: 0.8579 - val_loss: 0.6866 - val_acc: 0.7406
# Epoch 28/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 0.3286 - acc: 0.8829 - val_loss: 0.4919 - val_acc: 0.8222
# Epoch 29/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 0.3350 - acc: 0.8717 - val_loss: 0.3088 - val_acc: 0.8806
# Epoch 30/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 0.2342 - acc: 0.9242 - val_loss: 0.2660 - val_acc: 0.9106
# Epoch 31/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 0.2424 - acc: 0.9167 - val_loss: 0.2550 - val_acc: 0.9178
# Epoch 32/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 0.1634 - acc: 0.9454 - val_loss: 0.1591 - val_acc: 0.9472
# Epoch 33/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 0.2861 - acc: 0.8913 - val_loss: 0.4054 - val_acc: 0.8394
# Epoch 34/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 0.2274 - acc: 0.9204 - val_loss: 0.1252 - val_acc: 0.9611
# Epoch 35/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 0.1131 - acc: 0.9658 - val_loss: 0.1492 - val_acc: 0.9472
# Epoch 36/1000
# 2400/2400 [==============================] - 0s 74us/step - loss: 0.1342 - acc: 0.9546 - val_loss: 0.4607 - val_acc: 0.8483
# Epoch 37/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 0.1400 - acc: 0.9517 - val_loss: 0.1600 - val_acc: 0.9389
# Epoch 38/1000
# 2400/2400 [==============================] - 0s 62us/step - loss: 0.1176 - acc: 0.9596 - val_loss: 0.1304 - val_acc: 0.9517
# Epoch 39/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 0.0810 - acc: 0.9712 - val_loss: 0.1666 - val_acc: 0.9333
# Epoch 40/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 0.1644 - acc: 0.9383 - val_loss: 0.2683 - val_acc: 0.8950
# Epoch 41/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 0.1420 - acc: 0.9529 - val_loss: 0.1022 - val_acc: 0.9678
# Epoch 42/1000
# 2400/2400 [==============================] - 0s 70us/step - loss: 0.0684 - acc: 0.9821 - val_loss: 0.0980 - val_acc: 0.9678
# Epoch 43/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 0.0453 - acc: 0.9883 - val_loss: 0.0988 - val_acc: 0.9661
# Epoch 44/1000
# 2400/2400 [==============================] - 0s 69us/step - loss: 0.0409 - acc: 0.9904 - val_loss: 0.0870 - val_acc: 0.9683
# Epoch 45/1000
# 2400/2400 [==============================] - 0s 69us/step - loss: 0.0391 - acc: 0.9896 - val_loss: 0.0904 - val_acc: 0.9711
# Epoch 46/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 0.0917 - acc: 0.9687 - val_loss: 0.0880 - val_acc: 0.9711
# Epoch 47/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 0.0363 - acc: 0.9912 - val_loss: 0.0748 - val_acc: 0.9772
# Epoch 48/1000
# 2400/2400 [==============================] - 0s 65us/step - loss: 0.0339 - acc: 0.9917 - val_loss: 0.0672 - val_acc: 0.9756
# Epoch 49/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 0.0334 - acc: 0.9896 - val_loss: 0.1773 - val_acc: 0.9489
# Epoch 50/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 0.0369 - acc: 0.9917 - val_loss: 0.0611 - val_acc: 0.9833
# Epoch 51/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 0.2044 - acc: 0.9454 - val_loss: 0.1248 - val_acc: 0.9556
# Epoch 52/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 0.0399 - acc: 0.9904 - val_loss: 0.0626 - val_acc: 0.9811
# Epoch 53/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 0.0211 - acc: 0.9946 - val_loss: 0.0597 - val_acc: 0.9828
# Epoch 54/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 0.0161 - acc: 0.9983 - val_loss: 0.0621 - val_acc: 0.9839
# Epoch 55/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 0.0134 - acc: 0.9971 - val_loss: 0.1281 - val_acc: 0.9633
# Epoch 56/1000
# 2400/2400 [==============================] - 0s 59us/step - loss: 0.0472 - acc: 0.9875 - val_loss: 0.0519 - val_acc: 0.9839
# Epoch 57/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 0.0130 - acc: 0.9979 - val_loss: 0.0565 - val_acc: 0.9839
# Epoch 58/1000
# 2400/2400 [==============================] - 0s 62us/step - loss: 0.0091 - acc: 0.9983 - val_loss: 0.0588 - val_acc: 0.9839
# Epoch 59/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 0.0095 - acc: 0.9983 - val_loss: 0.0945 - val_acc: 0.9744
# Epoch 60/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 0.1366 - acc: 0.9617 - val_loss: 0.0538 - val_acc: 0.9833
# Epoch 61/1000
# 2400/2400 [==============================] - 0s 69us/step - loss: 0.0118 - acc: 0.9988 - val_loss: 0.0536 - val_acc: 0.9850
# Epoch 62/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 0.0098 - acc: 0.9988 - val_loss: 0.0663 - val_acc: 0.9800
# Epoch 63/1000
# 2400/2400 [==============================] - 0s 85us/step - loss: 0.0084 - acc: 0.9996 - val_loss: 0.0557 - val_acc: 0.9850
# Epoch 64/1000
# 2400/2400 [==============================] - 0s 70us/step - loss: 0.0079 - acc: 0.9975 - val_loss: 0.0588 - val_acc: 0.9806
# Epoch 65/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 0.0067 - acc: 0.9996 - val_loss: 0.0560 - val_acc: 0.9828
# Epoch 66/1000
# 2400/2400 [==============================] - 0s 69us/step - loss: 0.0052 - acc: 0.9992 - val_loss: 0.0635 - val_acc: 0.9850
# Epoch 67/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 0.0057 - acc: 0.9992 - val_loss: 0.0569 - val_acc: 0.9856
# Epoch 68/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 0.0041 - acc: 0.9996 - val_loss: 0.0598 - val_acc: 0.9839
# Epoch 69/1000
# 2400/2400 [==============================] - 0s 77us/step - loss: 0.0043 - acc: 0.9992 - val_loss: 0.0586 - val_acc: 0.9811
# Epoch 70/1000
# 2400/2400 [==============================] - 0s 79us/step - loss: 0.0044 - acc: 0.9996 - val_loss: 0.0994 - val_acc: 0.9756
# Epoch 71/1000
# 2400/2400 [==============================] - 0s 65us/step - loss: 0.2033 - acc: 0.9483 - val_loss: 0.0489 - val_acc: 0.9839
# Epoch 72/1000
# 2400/2400 [==============================] - 0s 88us/step - loss: 0.0070 - acc: 1.0000 - val_loss: 0.0501 - val_acc: 0.9856
# Epoch 73/1000
# 2400/2400 [==============================] - 0s 78us/step - loss: 0.0058 - acc: 1.0000 - val_loss: 0.0468 - val_acc: 0.9861
# Epoch 74/1000
# 2400/2400 [==============================] - 0s 74us/step - loss: 0.0053 - acc: 0.9992 - val_loss: 0.0517 - val_acc: 0.9850
# Epoch 75/1000
# 2400/2400 [==============================] - 0s 69us/step - loss: 0.0043 - acc: 0.9996 - val_loss: 0.0687 - val_acc: 0.9817
# Epoch 76/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 0.0054 - acc: 0.9996 - val_loss: 0.0512 - val_acc: 0.9872
# Epoch 77/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 0.0032 - acc: 1.0000 - val_loss: 0.0555 - val_acc: 0.9861
# Epoch 78/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 0.0039 - acc: 0.9996 - val_loss: 0.0520 - val_acc: 0.9867
# Epoch 79/1000
# 2400/2400 [==============================] - 0s 61us/step - loss: 0.0022 - acc: 1.0000 - val_loss: 0.0521 - val_acc: 0.9850
# Epoch 80/1000
# 2400/2400 [==============================] - 0s 77us/step - loss: 0.0027 - acc: 1.0000 - val_loss: 0.0575 - val_acc: 0.9833
# Epoch 81/1000
# 2400/2400 [==============================] - 0s 59us/step - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0582 - val_acc: 0.9850
# Epoch 82/1000
# 2400/2400 [==============================] - 0s 80us/step - loss: 0.0071 - acc: 0.9983 - val_loss: 0.0579 - val_acc: 0.9828
# Epoch 83/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 0.3256 - acc: 0.9375 - val_loss: 0.1436 - val_acc: 0.9511
# Epoch 84/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 0.0298 - acc: 0.9938 - val_loss: 0.0520 - val_acc: 0.9828
# Epoch 85/1000
# 2400/2400 [==============================] - 0s 70us/step - loss: 0.0105 - acc: 0.9988 - val_loss: 0.0501 - val_acc: 0.9844
# Epoch 86/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 0.0064 - acc: 0.9996 - val_loss: 0.0482 - val_acc: 0.9850
# Epoch 87/1000
# 2400/2400 [==============================] - 0s 69us/step - loss: 0.0043 - acc: 1.0000 - val_loss: 0.0523 - val_acc: 0.9850
# Epoch 88/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 0.0043 - acc: 1.0000 - val_loss: 0.0523 - val_acc: 0.9833
# Epoch 89/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 0.0041 - acc: 1.0000 - val_loss: 0.0542 - val_acc: 0.9828
# Epoch 90/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 0.0035 - acc: 1.0000 - val_loss: 0.0519 - val_acc: 0.9856
# Epoch 91/1000
# 2400/2400 [==============================] - 0s 57us/step - loss: 0.0031 - acc: 1.0000 - val_loss: 0.0531 - val_acc: 0.9861
# Epoch 92/1000
# 2400/2400 [==============================] - 0s 87us/step - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0536 - val_acc: 0.9861
# Epoch 93/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0576 - val_acc: 0.9839
# Epoch 94/1000
# 2400/2400 [==============================] - 0s 70us/step - loss: 0.0020 - acc: 0.9996 - val_loss: 0.0718 - val_acc: 0.9822
# Epoch 95/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 0.0025 - acc: 1.0000 - val_loss: 0.0583 - val_acc: 0.9844
# Epoch 96/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0582 - val_acc: 0.9850
# Epoch 97/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 0.0023 - acc: 0.9996 - val_loss: 0.0652 - val_acc: 0.9833
# Epoch 98/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 0.0028 - acc: 0.9992 - val_loss: 0.0679 - val_acc: 0.9839
# Epoch 99/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 0.0075 - acc: 0.9988 - val_loss: 0.3359 - val_acc: 0.9378
# Epoch 100/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 0.0531 - acc: 0.9892 - val_loss: 0.0494 - val_acc: 0.9856
# Epoch 101/1000
# 2400/2400 [==============================] - 0s 65us/step - loss: 0.0021 - acc: 1.0000 - val_loss: 0.0541 - val_acc: 0.9844
# Epoch 102/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0545 - val_acc: 0.9861
# Epoch 103/1000
# 2400/2400 [==============================] - 0s 62us/step - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0577 - val_acc: 0.9850
# Epoch 104/1000
# 2400/2400 [==============================] - 0s 62us/step - loss: 8.3050e-04 - acc: 1.0000 - val_loss: 0.0562 - val_acc: 0.9850
# Epoch 105/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0546 - val_acc: 0.9861
# Epoch 106/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 0.0010 - acc: 1.0000 - val_loss: 0.0598 - val_acc: 0.9861
# Epoch 107/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 8.3203e-04 - acc: 1.0000 - val_loss: 0.0598 - val_acc: 0.9856
# Epoch 108/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0762 - val_acc: 0.9839
# Epoch 109/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0636 - val_acc: 0.9861
# Epoch 110/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 7.1257e-04 - acc: 1.0000 - val_loss: 0.0576 - val_acc: 0.9861
# Epoch 111/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 9.7648e-04 - acc: 1.0000 - val_loss: 0.0584 - val_acc: 0.9856
# Epoch 112/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 0.0021 - acc: 0.9992 - val_loss: 0.0568 - val_acc: 0.9856
# Epoch 113/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 5.8971e-04 - acc: 1.0000 - val_loss: 0.0727 - val_acc: 0.9850
# Epoch 114/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 8.8161e-04 - acc: 1.0000 - val_loss: 0.0638 - val_acc: 0.9856
# Epoch 115/1000
# 2400/2400 [==============================] - 0s 62us/step - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0618 - val_acc: 0.9856
# Epoch 116/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 0.0045 - acc: 0.9988 - val_loss: 0.5404 - val_acc: 0.9117
# Epoch 117/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 0.1988 - acc: 0.9546 - val_loss: 0.0482 - val_acc: 0.9872
# Epoch 118/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 0.0040 - acc: 0.9996 - val_loss: 0.0464 - val_acc: 0.9883
# Epoch 119/1000
# 2400/2400 [==============================] - 0s 59us/step - loss: 0.0028 - acc: 0.9996 - val_loss: 0.0490 - val_acc: 0.9883
# Epoch 120/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0480 - val_acc: 0.9883
# Epoch 121/1000
# 2400/2400 [==============================] - 0s 77us/step - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0571 - val_acc: 0.9861
# Epoch 122/1000
# 2400/2400 [==============================] - 0s 89us/step - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0512 - val_acc: 0.9883
# Epoch 123/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 9.0490e-04 - acc: 1.0000 - val_loss: 0.0519 - val_acc: 0.9883
# Epoch 124/1000
# 2400/2400 [==============================] - 0s 84us/step - loss: 7.8208e-04 - acc: 1.0000 - val_loss: 0.0526 - val_acc: 0.9872
# Epoch 125/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 9.8722e-04 - acc: 1.0000 - val_loss: 0.0550 - val_acc: 0.9878
# Epoch 126/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 8.3879e-04 - acc: 1.0000 - val_loss: 0.0528 - val_acc: 0.9889
# Epoch 127/1000
# 2400/2400 [==============================] - 0s 69us/step - loss: 4.5473e-04 - acc: 1.0000 - val_loss: 0.0524 - val_acc: 0.9889
# Epoch 128/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 5.8497e-04 - acc: 1.0000 - val_loss: 0.0577 - val_acc: 0.9872
# Epoch 129/1000
# 2400/2400 [==============================] - 0s 80us/step - loss: 5.5767e-04 - acc: 1.0000 - val_loss: 0.0634 - val_acc: 0.9850
# Epoch 130/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 4.5549e-04 - acc: 1.0000 - val_loss: 0.0603 - val_acc: 0.9850
# Epoch 131/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 3.6832e-04 - acc: 1.0000 - val_loss: 0.0533 - val_acc: 0.9872
# Epoch 132/1000
# 2400/2400 [==============================] - 0s 83us/step - loss: 8.9480e-04 - acc: 1.0000 - val_loss: 0.0623 - val_acc: 0.9867
# Epoch 133/1000
# 2400/2400 [==============================] - 0s 81us/step - loss: 3.5644e-04 - acc: 1.0000 - val_loss: 0.0542 - val_acc: 0.9861
# Epoch 134/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 5.0395e-04 - acc: 1.0000 - val_loss: 0.0590 - val_acc: 0.9850
# Epoch 135/1000
# 2400/2400 [==============================] - 0s 61us/step - loss: 5.1987e-04 - acc: 1.0000 - val_loss: 0.0568 - val_acc: 0.9872
# Epoch 136/1000
# 2400/2400 [==============================] - 0s 90us/step - loss: 2.5502e-04 - acc: 1.0000 - val_loss: 0.0547 - val_acc: 0.9878
# Epoch 137/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 3.6802e-04 - acc: 1.0000 - val_loss: 0.0580 - val_acc: 0.9867
# Epoch 138/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 8.4422e-04 - acc: 1.0000 - val_loss: 0.0604 - val_acc: 0.9856
# Epoch 139/1000
# 2400/2400 [==============================] - 0s 85us/step - loss: 4.2337e-04 - acc: 1.0000 - val_loss: 0.0604 - val_acc: 0.9878
# Epoch 140/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 0.1567 - acc: 0.9671 - val_loss: 0.0498 - val_acc: 0.9850
# Epoch 141/1000
# 2400/2400 [==============================] - 0s 70us/step - loss: 0.0040 - acc: 0.9996 - val_loss: 0.0434 - val_acc: 0.9878
# Epoch 142/1000
# 2400/2400 [==============================] - 0s 70us/step - loss: 0.0020 - acc: 0.9996 - val_loss: 0.0422 - val_acc: 0.9883
# Epoch 143/1000
# 2400/2400 [==============================] - 0s 84us/step - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0458 - val_acc: 0.9872
# Epoch 144/1000
# 2400/2400 [==============================] - 0s 82us/step - loss: 8.6640e-04 - acc: 1.0000 - val_loss: 0.0449 - val_acc: 0.9878
# Epoch 145/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 7.4916e-04 - acc: 1.0000 - val_loss: 0.0478 - val_acc: 0.9856
# Epoch 146/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 7.7456e-04 - acc: 1.0000 - val_loss: 0.0525 - val_acc: 0.9878
# Epoch 147/1000
# 2400/2400 [==============================] - 0s 65us/step - loss: 8.8899e-04 - acc: 1.0000 - val_loss: 0.0510 - val_acc: 0.9850
# Epoch 148/1000
# 2400/2400 [==============================] - 0s 82us/step - loss: 4.9484e-04 - acc: 1.0000 - val_loss: 0.0517 - val_acc: 0.9878
# Epoch 149/1000
# 2400/2400 [==============================] - 0s 69us/step - loss: 5.5332e-04 - acc: 1.0000 - val_loss: 0.0575 - val_acc: 0.9861
# Epoch 150/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 3.9057e-04 - acc: 1.0000 - val_loss: 0.0531 - val_acc: 0.9872
# Epoch 151/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 5.5698e-04 - acc: 1.0000 - val_loss: 0.0544 - val_acc: 0.9850
# Epoch 152/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 5.3083e-04 - acc: 1.0000 - val_loss: 0.0633 - val_acc: 0.9856
# Epoch 153/1000
# 2400/2400 [==============================] - 0s 65us/step - loss: 2.2866e-04 - acc: 1.0000 - val_loss: 0.0607 - val_acc: 0.9861
# Epoch 154/1000
# 2400/2400 [==============================] - 0s 58us/step - loss: 2.6512e-04 - acc: 1.0000 - val_loss: 0.0562 - val_acc: 0.9861
# Epoch 155/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 2.2370e-04 - acc: 1.0000 - val_loss: 0.0587 - val_acc: 0.9850
# Epoch 156/1000
# 2400/2400 [==============================] - 0s 69us/step - loss: 3.1184e-04 - acc: 1.0000 - val_loss: 0.0676 - val_acc: 0.9856
# Epoch 157/1000
# 2400/2400 [==============================] - 0s 60us/step - loss: 1.8446e-04 - acc: 1.0000 - val_loss: 0.0657 - val_acc: 0.9861
# Epoch 158/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 1.4286e-04 - acc: 1.0000 - val_loss: 0.0655 - val_acc: 0.9861
# Epoch 159/1000
# 2400/2400 [==============================] - 0s 62us/step - loss: 1.8612e-04 - acc: 1.0000 - val_loss: 0.0641 - val_acc: 0.9856
# Epoch 160/1000
# 2400/2400 [==============================] - 0s 65us/step - loss: 8.0660e-04 - acc: 1.0000 - val_loss: 0.0638 - val_acc: 0.9872
# Epoch 161/1000
# 2400/2400 [==============================] - 0s 65us/step - loss: 2.2755e-04 - acc: 1.0000 - val_loss: 0.0616 - val_acc: 0.9861
# Epoch 162/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 2.0902e-04 - acc: 1.0000 - val_loss: 0.0671 - val_acc: 0.9872
# Epoch 163/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 2.0813e-04 - acc: 1.0000 - val_loss: 0.0637 - val_acc: 0.9867
# Epoch 164/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 1.4749e-04 - acc: 1.0000 - val_loss: 0.0678 - val_acc: 0.9856
# Epoch 165/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 1.6660e-04 - acc: 1.0000 - val_loss: 0.0639 - val_acc: 0.9872
# Epoch 166/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 1.2089e-04 - acc: 1.0000 - val_loss: 0.0650 - val_acc: 0.9878
# Epoch 167/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 6.0661e-04 - acc: 1.0000 - val_loss: 0.0547 - val_acc: 0.9872
# Epoch 168/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 0.1385 - acc: 0.9754 - val_loss: 0.0457 - val_acc: 0.9850
# Epoch 169/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0435 - val_acc: 0.9883
# Epoch 170/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 5.1857e-04 - acc: 1.0000 - val_loss: 0.0449 - val_acc: 0.9889
# Epoch 171/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 5.0566e-04 - acc: 1.0000 - val_loss: 0.0464 - val_acc: 0.9883
# Epoch 172/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 6.4290e-04 - acc: 1.0000 - val_loss: 0.0468 - val_acc: 0.9883
# Epoch 173/1000
# 2400/2400 [==============================] - 0s 62us/step - loss: 4.4857e-04 - acc: 1.0000 - val_loss: 0.0476 - val_acc: 0.9883
# Epoch 174/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 4.0476e-04 - acc: 1.0000 - val_loss: 0.0498 - val_acc: 0.9883
# Epoch 175/1000
# 2400/2400 [==============================] - 0s 69us/step - loss: 3.0306e-04 - acc: 1.0000 - val_loss: 0.0530 - val_acc: 0.9883
# Epoch 176/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 3.9823e-04 - acc: 1.0000 - val_loss: 0.0570 - val_acc: 0.9872
# Epoch 177/1000
# 2400/2400 [==============================] - 0s 70us/step - loss: 3.6302e-04 - acc: 1.0000 - val_loss: 0.0618 - val_acc: 0.9861
# Epoch 178/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 4.2880e-04 - acc: 1.0000 - val_loss: 0.0650 - val_acc: 0.9856
# Epoch 179/1000
# 2400/2400 [==============================] - 0s 62us/step - loss: 2.1680e-04 - acc: 1.0000 - val_loss: 0.0611 - val_acc: 0.9867
# Epoch 180/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 2.8271e-04 - acc: 1.0000 - val_loss: 0.0599 - val_acc: 0.9867
# Epoch 181/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 2.5253e-04 - acc: 1.0000 - val_loss: 0.0573 - val_acc: 0.9872
# Epoch 182/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 1.7706e-04 - acc: 1.0000 - val_loss: 0.0620 - val_acc: 0.9861
# Epoch 183/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 2.3650e-04 - acc: 1.0000 - val_loss: 0.0605 - val_acc: 0.9867
# Epoch 184/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 2.1327e-04 - acc: 1.0000 - val_loss: 0.0637 - val_acc: 0.9850
# Epoch 185/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 2.0181e-04 - acc: 1.0000 - val_loss: 0.0638 - val_acc: 0.9861
# Epoch 186/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 1.9310e-04 - acc: 1.0000 - val_loss: 0.0627 - val_acc: 0.9861
# Epoch 187/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 1.1248e-04 - acc: 1.0000 - val_loss: 0.0629 - val_acc: 0.9878
# Epoch 188/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 5.3310e-04 - acc: 1.0000 - val_loss: 0.0731 - val_acc: 0.9872
# Epoch 189/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 1.2299e-04 - acc: 1.0000 - val_loss: 0.0736 - val_acc: 0.9856
# Epoch 190/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 2.5742e-04 - acc: 1.0000 - val_loss: 0.0669 - val_acc: 0.9872
# Epoch 191/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 3.6439e-04 - acc: 1.0000 - val_loss: 0.0868 - val_acc: 0.9844
# Epoch 192/1000
# 2400/2400 [==============================] - 0s 65us/step - loss: 0.0451 - acc: 0.9879 - val_loss: 0.0618 - val_acc: 0.9867
# Epoch 193/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 7.6751e-04 - acc: 1.0000 - val_loss: 0.0588 - val_acc: 0.9867
# Epoch 194/1000
# 2400/2400 [==============================] - 0s 80us/step - loss: 4.6041e-04 - acc: 1.0000 - val_loss: 0.0611 - val_acc: 0.9844
# Epoch 195/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 3.8910e-04 - acc: 1.0000 - val_loss: 0.0562 - val_acc: 0.9856
# Epoch 196/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 3.6760e-04 - acc: 1.0000 - val_loss: 0.0572 - val_acc: 0.9867
# Epoch 197/1000
# 2400/2400 [==============================] - 0s 74us/step - loss: 2.0218e-04 - acc: 1.0000 - val_loss: 0.0567 - val_acc: 0.9872
# Epoch 198/1000
# 2400/2400 [==============================] - 0s 65us/step - loss: 2.9275e-04 - acc: 1.0000 - val_loss: 0.0578 - val_acc: 0.9872
# Epoch 199/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 2.1481e-04 - acc: 1.0000 - val_loss: 0.0600 - val_acc: 0.9878
# Epoch 200/1000
# 2400/2400 [==============================] - 0s 69us/step - loss: 1.9570e-04 - acc: 1.0000 - val_loss: 0.0624 - val_acc: 0.9872
# Epoch 201/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 1.7503e-04 - acc: 1.0000 - val_loss: 0.0586 - val_acc: 0.9867
# Epoch 202/1000
# 2400/2400 [==============================] - 0s 62us/step - loss: 3.9451e-04 - acc: 1.0000 - val_loss: 0.0636 - val_acc: 0.9861
# Epoch 203/1000
# 2400/2400 [==============================] - 0s 88us/step - loss: 1.2349e-04 - acc: 1.0000 - val_loss: 0.0623 - val_acc: 0.9867
# Epoch 204/1000
# 2400/2400 [==============================] - 0s 69us/step - loss: 1.9885e-04 - acc: 1.0000 - val_loss: 0.0629 - val_acc: 0.9872
# Epoch 205/1000
# 2400/2400 [==============================] - 0s 60us/step - loss: 9.2802e-05 - acc: 1.0000 - val_loss: 0.0611 - val_acc: 0.9867
# Epoch 206/1000
# 2400/2400 [==============================] - 0s 75us/step - loss: 1.1168e-04 - acc: 1.0000 - val_loss: 0.0685 - val_acc: 0.9856
# Epoch 207/1000
# 2400/2400 [==============================] - 0s 62us/step - loss: 1.8171e-04 - acc: 1.0000 - val_loss: 0.0648 - val_acc: 0.9861
# Epoch 208/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 2.9152e-04 - acc: 1.0000 - val_loss: 0.0714 - val_acc: 0.9844
# Epoch 209/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 1.3188e-04 - acc: 1.0000 - val_loss: 0.0639 - val_acc: 0.9861
# Epoch 210/1000
# 2400/2400 [==============================] - 0s 78us/step - loss: 6.2513e-05 - acc: 1.0000 - val_loss: 0.0635 - val_acc: 0.9861
# Epoch 211/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 6.1558e-04 - acc: 1.0000 - val_loss: 0.0583 - val_acc: 0.9872
# Epoch 212/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 9.2102e-05 - acc: 1.0000 - val_loss: 0.0583 - val_acc: 0.9878
# Epoch 213/1000
# 2400/2400 [==============================] - 0s 65us/step - loss: 5.5603e-05 - acc: 1.0000 - val_loss: 0.0586 - val_acc: 0.9883
# Epoch 214/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 1.3136e-04 - acc: 1.0000 - val_loss: 0.0632 - val_acc: 0.9861
# Epoch 215/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 3.9820e-04 - acc: 1.0000 - val_loss: 0.0660 - val_acc: 0.9872
# Epoch 216/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 0.0014 - acc: 0.9992 - val_loss: 0.1084 - val_acc: 0.9794
# Epoch 217/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 6.7486e-04 - acc: 0.9996 - val_loss: 0.0632 - val_acc: 0.9872
# Epoch 218/1000
# 2400/2400 [==============================] - 0s 74us/step - loss: 1.7362e-04 - acc: 1.0000 - val_loss: 0.0654 - val_acc: 0.9872
# Epoch 219/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 1.7843e-04 - acc: 1.0000 - val_loss: 0.0713 - val_acc: 0.9867
# Epoch 220/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 9.0619e-05 - acc: 1.0000 - val_loss: 0.0688 - val_acc: 0.9867
# Epoch 221/1000
# 2400/2400 [==============================] - 0s 65us/step - loss: 1.5117e-04 - acc: 1.0000 - val_loss: 0.0679 - val_acc: 0.9861
# Epoch 222/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 6.9249e-05 - acc: 1.0000 - val_loss: 0.0684 - val_acc: 0.9867
# Epoch 223/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 5.1421e-05 - acc: 1.0000 - val_loss: 0.0670 - val_acc: 0.9867
# Epoch 224/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 8.8135e-05 - acc: 1.0000 - val_loss: 0.0711 - val_acc: 0.9856
# Epoch 225/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 6.5266e-05 - acc: 1.0000 - val_loss: 0.0668 - val_acc: 0.9856
# Epoch 226/1000
# 2400/2400 [==============================] - 0s 53us/step - loss: 1.2719e-04 - acc: 1.0000 - val_loss: 0.0767 - val_acc: 0.9856
# Epoch 227/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 8.0836e-05 - acc: 1.0000 - val_loss: 0.0736 - val_acc: 0.9850
# Epoch 228/1000
# 2400/2400 [==============================] - 0s 55us/step - loss: 5.0702e-04 - acc: 1.0000 - val_loss: 0.2347 - val_acc: 0.9606
# Epoch 229/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 0.0028 - acc: 0.9988 - val_loss: 0.0839 - val_acc: 0.9850
# Epoch 230/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 1.1146e-04 - acc: 1.0000 - val_loss: 0.0795 - val_acc: 0.9850
# Epoch 231/1000
# 2400/2400 [==============================] - 0s 77us/step - loss: 1.2445e-04 - acc: 1.0000 - val_loss: 0.0670 - val_acc: 0.9867
# Epoch 232/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 3.3292e-04 - acc: 1.0000 - val_loss: 0.0788 - val_acc: 0.9844
# Epoch 233/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 1.8023e-04 - acc: 1.0000 - val_loss: 0.0732 - val_acc: 0.9856
# Epoch 234/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 6.4848e-05 - acc: 1.0000 - val_loss: 0.0706 - val_acc: 0.9856
# Epoch 235/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 9.0180e-05 - acc: 1.0000 - val_loss: 0.0674 - val_acc: 0.9872
# Epoch 236/1000
# 2400/2400 [==============================] - 0s 98us/step - loss: 5.6839e-05 - acc: 1.0000 - val_loss: 0.0660 - val_acc: 0.9872
# Epoch 237/1000
# 2400/2400 [==============================] - 0s 77us/step - loss: 4.0200e-05 - acc: 1.0000 - val_loss: 0.0647 - val_acc: 0.9867
# Epoch 238/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 9.4989e-05 - acc: 1.0000 - val_loss: 0.0708 - val_acc: 0.9872
# Epoch 239/1000
# 2400/2400 [==============================] - 0s 99us/step - loss: 4.7028e-05 - acc: 1.0000 - val_loss: 0.0667 - val_acc: 0.9867
# Epoch 240/1000
# 2400/2400 [==============================] - 0s 80us/step - loss: 6.8977e-05 - acc: 1.0000 - val_loss: 0.0717 - val_acc: 0.9872
# Epoch 241/1000
# 2400/2400 [==============================] - 0s 75us/step - loss: 6.3565e-05 - acc: 1.0000 - val_loss: 0.0730 - val_acc: 0.9872
# Epoch 242/1000
# 2400/2400 [==============================] - 0s 85us/step - loss: 5.3366e-05 - acc: 1.0000 - val_loss: 0.0697 - val_acc: 0.9872
# Epoch 243/1000
# 2400/2400 [==============================] - 0s 85us/step - loss: 3.6505e-05 - acc: 1.0000 - val_loss: 0.0668 - val_acc: 0.9872
# Epoch 244/1000
# 2400/2400 [==============================] - 0s 78us/step - loss: 2.7998e-05 - acc: 1.0000 - val_loss: 0.0668 - val_acc: 0.9867
# Epoch 245/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 3.6774e-05 - acc: 1.0000 - val_loss: 0.0656 - val_acc: 0.9872
# Epoch 246/1000
# 2400/2400 [==============================] - 0s 79us/step - loss: 4.7502e-05 - acc: 1.0000 - val_loss: 0.0717 - val_acc: 0.9861
# Epoch 247/1000
# 2400/2400 [==============================] - 0s 90us/step - loss: 5.4782e-05 - acc: 1.0000 - val_loss: 0.0647 - val_acc: 0.9867
# Epoch 248/1000
# 2400/2400 [==============================] - 0s 82us/step - loss: 1.6712e-04 - acc: 1.0000 - val_loss: 0.1288 - val_acc: 0.9778
# Epoch 249/1000
# 2400/2400 [==============================] - 0s 75us/step - loss: 0.0105 - acc: 0.9975 - val_loss: 0.0714 - val_acc: 0.9867
# Epoch 250/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 1.4802e-04 - acc: 1.0000 - val_loss: 0.0736 - val_acc: 0.9861
# Epoch 251/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 3.1310e-04 - acc: 1.0000 - val_loss: 0.0957 - val_acc: 0.9817
# Epoch 252/1000
# 2400/2400 [==============================] - 0s 74us/step - loss: 1.5372e-04 - acc: 1.0000 - val_loss: 0.0705 - val_acc: 0.9856
# Epoch 253/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 1.7393e-04 - acc: 1.0000 - val_loss: 0.0805 - val_acc: 0.9839
# Epoch 254/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 1.2252e-04 - acc: 1.0000 - val_loss: 0.0727 - val_acc: 0.9889
# Epoch 255/1000
# 2400/2400 [==============================] - 0s 70us/step - loss: 5.2547e-05 - acc: 1.0000 - val_loss: 0.0716 - val_acc: 0.9878
# Epoch 256/1000
# 2400/2400 [==============================] - 0s 75us/step - loss: 6.3885e-05 - acc: 1.0000 - val_loss: 0.0694 - val_acc: 0.9878
# Epoch 257/1000
# 2400/2400 [==============================] - 0s 88us/step - loss: 6.4945e-05 - acc: 1.0000 - val_loss: 0.0667 - val_acc: 0.9878
# Epoch 258/1000
# 2400/2400 [==============================] - 0s 80us/step - loss: 4.9151e-05 - acc: 1.0000 - val_loss: 0.0696 - val_acc: 0.9878
# Epoch 259/1000
# 2400/2400 [==============================] - 0s 84us/step - loss: 5.6013e-05 - acc: 1.0000 - val_loss: 0.0720 - val_acc: 0.9883
# Epoch 260/1000
# 2400/2400 [==============================] - 0s 75us/step - loss: 9.2183e-05 - acc: 1.0000 - val_loss: 0.0701 - val_acc: 0.9878
# Epoch 261/1000
# 2400/2400 [==============================] - 0s 77us/step - loss: 8.9650e-05 - acc: 1.0000 - val_loss: 0.0685 - val_acc: 0.9878
# Epoch 262/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 4.1398e-05 - acc: 1.0000 - val_loss: 0.0727 - val_acc: 0.9872
# Epoch 263/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 9.6612e-05 - acc: 1.0000 - val_loss: 0.0762 - val_acc: 0.9861
# Epoch 264/1000
# 2400/2400 [==============================] - 0s 70us/step - loss: 5.3165e-05 - acc: 1.0000 - val_loss: 0.0741 - val_acc: 0.9878
# Epoch 265/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 5.8780e-05 - acc: 1.0000 - val_loss: 0.0752 - val_acc: 0.9878
# Epoch 266/1000
# 2400/2400 [==============================] - 0s 79us/step - loss: 5.6939e-05 - acc: 1.0000 - val_loss: 0.0747 - val_acc: 0.9872
# Epoch 267/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 2.6688e-05 - acc: 1.0000 - val_loss: 0.0730 - val_acc: 0.9878
# Epoch 268/1000
# 2400/2400 [==============================] - 0s 59us/step - loss: 2.2480e-05 - acc: 1.0000 - val_loss: 0.0740 - val_acc: 0.9878
# Epoch 269/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 3.3014e-05 - acc: 1.0000 - val_loss: 0.0748 - val_acc: 0.9878
# Epoch 270/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 5.1469e-05 - acc: 1.0000 - val_loss: 0.0747 - val_acc: 0.9883
# Epoch 271/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 9.1302e-05 - acc: 1.0000 - val_loss: 0.0775 - val_acc: 0.9861
# Epoch 272/1000
# 2400/2400 [==============================] - 0s 87us/step - loss: 3.1101e-05 - acc: 1.0000 - val_loss: 0.0753 - val_acc: 0.9878
# Epoch 273/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 3.6033e-05 - acc: 1.0000 - val_loss: 0.0730 - val_acc: 0.9878
# Epoch 274/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 5.5872e-05 - acc: 1.0000 - val_loss: 0.0741 - val_acc: 0.9878
# Epoch 275/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 3.8478e-05 - acc: 1.0000 - val_loss: 0.0757 - val_acc: 0.9878
# Epoch 276/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 5.2368e-05 - acc: 1.0000 - val_loss: 0.0768 - val_acc: 0.9883
# Epoch 277/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 3.0766e-05 - acc: 1.0000 - val_loss: 0.0765 - val_acc: 0.9883
# Epoch 278/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 3.6546e-05 - acc: 1.0000 - val_loss: 0.0752 - val_acc: 0.9878
# Epoch 279/1000
# 2400/2400 [==============================] - 0s 65us/step - loss: 4.0520e-05 - acc: 1.0000 - val_loss: 0.0737 - val_acc: 0.9878
# Epoch 280/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 2.9067e-05 - acc: 1.0000 - val_loss: 0.0773 - val_acc: 0.9867
# Epoch 281/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 2.5233e-05 - acc: 1.0000 - val_loss: 0.0730 - val_acc: 0.9878
# Epoch 282/1000
# 2400/2400 [==============================] - 0s 65us/step - loss: 4.1265e-05 - acc: 1.0000 - val_loss: 0.0751 - val_acc: 0.9883
# Epoch 283/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 2.3018e-05 - acc: 1.0000 - val_loss: 0.0749 - val_acc: 0.9883
# Epoch 284/1000
# 2400/2400 [==============================] - 0s 65us/step - loss: 2.5363e-05 - acc: 1.0000 - val_loss: 0.0765 - val_acc: 0.9878
# Epoch 285/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 2.8809e-05 - acc: 1.0000 - val_loss: 0.0761 - val_acc: 0.9878
# Epoch 286/1000
# 2400/2400 [==============================] - 0s 77us/step - loss: 9.3352e-04 - acc: 1.0000 - val_loss: 0.0825 - val_acc: 0.9861
# Epoch 287/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 2.6663e-04 - acc: 1.0000 - val_loss: 0.0773 - val_acc: 0.9867
# Epoch 288/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 5.1208e-05 - acc: 1.0000 - val_loss: 0.0757 - val_acc: 0.9861
# Epoch 289/1000
# 2400/2400 [==============================] - 0s 58us/step - loss: 3.4975e-05 - acc: 1.0000 - val_loss: 0.0733 - val_acc: 0.9867
# Epoch 290/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 1.7612e-05 - acc: 1.0000 - val_loss: 0.0729 - val_acc: 0.9867
# Epoch 291/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 7.9026e-05 - acc: 1.0000 - val_loss: 0.0733 - val_acc: 0.9844
# Epoch 292/1000
# 2400/2400 [==============================] - 0s 83us/step - loss: 2.4104e-04 - acc: 1.0000 - val_loss: 0.0773 - val_acc: 0.9878
# Epoch 293/1000
# 2400/2400 [==============================] - 0s 84us/step - loss: 0.0105 - acc: 0.9967 - val_loss: 0.5282 - val_acc: 0.9278
# Epoch 294/1000
# 2400/2400 [==============================] - 0s 81us/step - loss: 0.0620 - acc: 0.9904 - val_loss: 0.0522 - val_acc: 0.9889
# Epoch 295/1000
# 2400/2400 [==============================] - 0s 61us/step - loss: 0.0013 - acc: 0.9996 - val_loss: 0.0591 - val_acc: 0.9878
# Epoch 296/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 2.0370e-04 - acc: 1.0000 - val_loss: 0.0584 - val_acc: 0.9878
# Epoch 297/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 1.5444e-04 - acc: 1.0000 - val_loss: 0.0573 - val_acc: 0.9883
# Epoch 298/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 1.4058e-04 - acc: 1.0000 - val_loss: 0.0571 - val_acc: 0.9883
# Epoch 299/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 1.2808e-04 - acc: 1.0000 - val_loss: 0.0578 - val_acc: 0.9883
# Epoch 300/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 1.3940e-04 - acc: 1.0000 - val_loss: 0.0602 - val_acc: 0.9872
# Epoch 301/1000
# 2400/2400 [==============================] - 0s 80us/step - loss: 1.0651e-04 - acc: 1.0000 - val_loss: 0.0607 - val_acc: 0.9878
# Epoch 302/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 1.6322e-04 - acc: 1.0000 - val_loss: 0.0631 - val_acc: 0.9872
# Epoch 303/1000
# 2400/2400 [==============================] - 0s 83us/step - loss: 6.7514e-05 - acc: 1.0000 - val_loss: 0.0634 - val_acc: 0.9872
# Epoch 304/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 6.2335e-05 - acc: 1.0000 - val_loss: 0.0634 - val_acc: 0.9878
# Epoch 305/1000
# 2400/2400 [==============================] - 0s 70us/step - loss: 8.3176e-05 - acc: 1.0000 - val_loss: 0.0616 - val_acc: 0.9878
# Epoch 306/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 1.7859e-04 - acc: 1.0000 - val_loss: 0.0681 - val_acc: 0.9867
# Epoch 307/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 6.9273e-05 - acc: 1.0000 - val_loss: 0.0676 - val_acc: 0.9867
# Epoch 308/1000
# 2400/2400 [==============================] - 0s 70us/step - loss: 7.0293e-05 - acc: 1.0000 - val_loss: 0.0652 - val_acc: 0.9878
# Epoch 309/1000
# 2400/2400 [==============================] - 0s 60us/step - loss: 5.8335e-04 - acc: 0.9996 - val_loss: 0.0789 - val_acc: 0.9861
# Epoch 310/1000
# 2400/2400 [==============================] - 0s 65us/step - loss: 1.0393e-04 - acc: 1.0000 - val_loss: 0.0730 - val_acc: 0.9856
# Epoch 311/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 4.9576e-05 - acc: 1.0000 - val_loss: 0.0704 - val_acc: 0.9861
# Epoch 312/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 6.0218e-05 - acc: 1.0000 - val_loss: 0.0703 - val_acc: 0.9872
# Epoch 313/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 5.0088e-05 - acc: 1.0000 - val_loss: 0.0690 - val_acc: 0.9872
# Epoch 314/1000
# 2400/2400 [==============================] - 0s 69us/step - loss: 6.4659e-05 - acc: 1.0000 - val_loss: 0.0725 - val_acc: 0.9867
# Epoch 315/1000
# 2400/2400 [==============================] - 0s 85us/step - loss: 1.6160e-04 - acc: 1.0000 - val_loss: 0.0690 - val_acc: 0.9872
# Epoch 316/1000
# 2400/2400 [==============================] - 0s 70us/step - loss: 4.0955e-05 - acc: 1.0000 - val_loss: 0.0697 - val_acc: 0.9872
# Epoch 317/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 5.8923e-05 - acc: 1.0000 - val_loss: 0.0699 - val_acc: 0.9900
# Epoch 318/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 5.1649e-05 - acc: 1.0000 - val_loss: 0.0683 - val_acc: 0.9883
# Epoch 319/1000
# 2400/2400 [==============================] - 0s 74us/step - loss: 5.0438e-05 - acc: 1.0000 - val_loss: 0.0645 - val_acc: 0.9883
# Epoch 320/1000
# 2400/2400 [==============================] - 0s 74us/step - loss: 4.1649e-05 - acc: 1.0000 - val_loss: 0.0655 - val_acc: 0.9883
# Epoch 321/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 3.6678e-05 - acc: 1.0000 - val_loss: 0.0658 - val_acc: 0.9883
# Epoch 322/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 4.4769e-05 - acc: 1.0000 - val_loss: 0.0659 - val_acc: 0.9883
# Epoch 323/1000
# 2400/2400 [==============================] - 0s 74us/step - loss: 5.0574e-05 - acc: 1.0000 - val_loss: 0.0683 - val_acc: 0.9883
# Epoch 324/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 4.8667e-05 - acc: 1.0000 - val_loss: 0.0688 - val_acc: 0.9872
# Epoch 325/1000
# 2400/2400 [==============================] - 0s 74us/step - loss: 2.5752e-05 - acc: 1.0000 - val_loss: 0.0702 - val_acc: 0.9872
# Epoch 326/1000
# 2400/2400 [==============================] - 0s 62us/step - loss: 3.6917e-05 - acc: 1.0000 - val_loss: 0.0687 - val_acc: 0.9878
# Epoch 327/1000
# 2400/2400 [==============================] - 0s 69us/step - loss: 6.6307e-05 - acc: 1.0000 - val_loss: 0.0714 - val_acc: 0.9861
# Epoch 328/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 9.7533e-04 - acc: 0.9996 - val_loss: 0.0937 - val_acc: 0.9856
# Epoch 329/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 1.4266e-04 - acc: 1.0000 - val_loss: 0.0779 - val_acc: 0.9872
# Epoch 330/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 4.4279e-05 - acc: 1.0000 - val_loss: 0.0768 - val_acc: 0.9867
# Epoch 331/1000
# 2400/2400 [==============================] - 0s 84us/step - loss: 1.9571e-05 - acc: 1.0000 - val_loss: 0.0769 - val_acc: 0.9867
# Epoch 332/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 3.0250e-05 - acc: 1.0000 - val_loss: 0.0751 - val_acc: 0.9872
# Epoch 333/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 2.9762e-05 - acc: 1.0000 - val_loss: 0.0763 - val_acc: 0.9867
# Epoch 334/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 2.5994e-05 - acc: 1.0000 - val_loss: 0.0747 - val_acc: 0.9872
# Epoch 335/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 1.6287e-05 - acc: 1.0000 - val_loss: 0.0746 - val_acc: 0.9872
# Epoch 336/1000
# 2400/2400 [==============================] - 0s 58us/step - loss: 4.2407e-05 - acc: 1.0000 - val_loss: 0.0788 - val_acc: 0.9856
# Epoch 337/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 1.9866e-05 - acc: 1.0000 - val_loss: 0.0773 - val_acc: 0.9861
# Epoch 338/1000
# 2400/2400 [==============================] - 0s 75us/step - loss: 3.7953e-05 - acc: 1.0000 - val_loss: 0.0785 - val_acc: 0.9861
# Epoch 339/1000
# 2400/2400 [==============================] - 0s 61us/step - loss: 2.5717e-05 - acc: 1.0000 - val_loss: 0.0769 - val_acc: 0.9861
# Epoch 340/1000
# ...
# Epoch 890/1000
# 2400/2400 [==============================] - 0s 70us/step - loss: 2.0863e-06 - acc: 1.0000 - val_loss: 0.0964 - val_acc: 0.9878
# Epoch 891/1000
# 2400/2400 [==============================] - 0s 70us/step - loss: 4.5078e-06 - acc: 1.0000 - val_loss: 0.0956 - val_acc: 0.9872
# Epoch 892/1000
# 2400/2400 [==============================] - 0s 65us/step - loss: 1.9900e-06 - acc: 1.0000 - val_loss: 0.0957 - val_acc: 0.9872
# Epoch 893/1000
# 2400/2400 [==============================] - 0s 77us/step - loss: 2.5388e-06 - acc: 1.0000 - val_loss: 0.0955 - val_acc: 0.9878
# Epoch 894/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 9.2057e-06 - acc: 1.0000 - val_loss: 0.0948 - val_acc: 0.9878
# Epoch 895/1000
# 2400/2400 [==============================] - 0s 83us/step - loss: 1.8096e-06 - acc: 1.0000 - val_loss: 0.0945 - val_acc: 0.9878
# Epoch 896/1000
# 2400/2400 [==============================] - 0s 56us/step - loss: 2.3542e-06 - acc: 1.0000 - val_loss: 0.0945 - val_acc: 0.9878
# Epoch 897/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 3.9720e-06 - acc: 1.0000 - val_loss: 0.0942 - val_acc: 0.9878
# Epoch 898/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 6.0383e-06 - acc: 1.0000 - val_loss: 0.0940 - val_acc: 0.9878
# Epoch 899/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 1.6853e-05 - acc: 1.0000 - val_loss: 0.0914 - val_acc: 0.9878
# Epoch 900/1000
# 2400/2400 [==============================] - 0s 61us/step - loss: 2.7521e-06 - acc: 1.0000 - val_loss: 0.0913 - val_acc: 0.9878
# Epoch 901/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 2.8630e-06 - acc: 1.0000 - val_loss: 0.0914 - val_acc: 0.9878
# Epoch 902/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 2.9804e-06 - acc: 1.0000 - val_loss: 0.0910 - val_acc: 0.9878
# Epoch 903/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 2.4105e-06 - acc: 1.0000 - val_loss: 0.0911 - val_acc: 0.9878
# Epoch 904/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 1.8262e-06 - acc: 1.0000 - val_loss: 0.0909 - val_acc: 0.9878
# Epoch 905/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 2.6558e-06 - acc: 1.0000 - val_loss: 0.0909 - val_acc: 0.9883
# Epoch 906/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 7.3325e-06 - acc: 1.0000 - val_loss: 0.0926 - val_acc: 0.9878
# Epoch 907/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 4.4676e-06 - acc: 1.0000 - val_loss: 0.0923 - val_acc: 0.9878
# Epoch 908/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 6.8695e-06 - acc: 1.0000 - val_loss: 0.0912 - val_acc: 0.9883
# Epoch 909/1000
# 2400/2400 [==============================] - 0s 69us/step - loss: 4.8084e-06 - acc: 1.0000 - val_loss: 0.0916 - val_acc: 0.9878
# Epoch 910/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 4.4101e-06 - acc: 1.0000 - val_loss: 0.0914 - val_acc: 0.9878
# Epoch 911/1000
# 2400/2400 [==============================] - 0s 75us/step - loss: 2.9782e-06 - acc: 1.0000 - val_loss: 0.0911 - val_acc: 0.9878
# Epoch 912/1000
# 2400/2400 [==============================] - 0s 65us/step - loss: 2.3162e-06 - acc: 1.0000 - val_loss: 0.0910 - val_acc: 0.9878
# Epoch 913/1000
# 2400/2400 [==============================] - 0s 65us/step - loss: 6.9670e-06 - acc: 1.0000 - val_loss: 0.0904 - val_acc: 0.9878
# Epoch 914/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 4.6401e-06 - acc: 1.0000 - val_loss: 0.0893 - val_acc: 0.9878
# Epoch 915/1000
# 2400/2400 [==============================] - 0s 69us/step - loss: 2.6578e-06 - acc: 1.0000 - val_loss: 0.0899 - val_acc: 0.9878
# Epoch 916/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 8.8098e-07 - acc: 1.0000 - val_loss: 0.0898 - val_acc: 0.9878
# Epoch 917/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 5.5831e-06 - acc: 1.0000 - val_loss: 0.0935 - val_acc: 0.9872
# Epoch 918/1000
# 2400/2400 [==============================] - 0s 74us/step - loss: 3.9008e-06 - acc: 1.0000 - val_loss: 0.0944 - val_acc: 0.9867
# Epoch 919/1000
# 2400/2400 [==============================] - 0s 80us/step - loss: 7.1685e-06 - acc: 1.0000 - val_loss: 0.0971 - val_acc: 0.9878
# Epoch 920/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 6.5674e-06 - acc: 1.0000 - val_loss: 0.0970 - val_acc: 0.9867
# Epoch 921/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 7.8138e-06 - acc: 1.0000 - val_loss: 0.0958 - val_acc: 0.9867
# Epoch 922/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 1.9535e-06 - acc: 1.0000 - val_loss: 0.0955 - val_acc: 0.9867
# Epoch 923/1000
# 2400/2400 [==============================] - 0s 77us/step - loss: 6.4807e-06 - acc: 1.0000 - val_loss: 0.0949 - val_acc: 0.9872
# Epoch 924/1000
# 2400/2400 [==============================] - 0s 65us/step - loss: 1.7998e-06 - acc: 1.0000 - val_loss: 0.0948 - val_acc: 0.9872
# Epoch 925/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 3.1272e-06 - acc: 1.0000 - val_loss: 0.0947 - val_acc: 0.9872
# Epoch 926/1000
# 2400/2400 [==============================] - 0s 65us/step - loss: 4.5244e-06 - acc: 1.0000 - val_loss: 0.0948 - val_acc: 0.9872
# Epoch 927/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 1.3569e-06 - acc: 1.0000 - val_loss: 0.0947 - val_acc: 0.9872
# Epoch 928/1000
# 2400/2400 [==============================] - 0s 61us/step - loss: 5.7962e-06 - acc: 1.0000 - val_loss: 0.0943 - val_acc: 0.9878
# Epoch 929/1000
# 2400/2400 [==============================] - 0s 84us/step - loss: 2.0460e-06 - acc: 1.0000 - val_loss: 0.0944 - val_acc: 0.9878
# Epoch 930/1000
# 2400/2400 [==============================] - 0s 61us/step - loss: 2.4380e-06 - acc: 1.0000 - val_loss: 0.0945 - val_acc: 0.9878
# Epoch 931/1000
# 2400/2400 [==============================] - 0s 70us/step - loss: 2.7105e-06 - acc: 1.0000 - val_loss: 0.0944 - val_acc: 0.9878
# Epoch 932/1000
# 2400/2400 [==============================] - 0s 60us/step - loss: 2.8979e-06 - acc: 1.0000 - val_loss: 0.0942 - val_acc: 0.9872
# Epoch 933/1000
# 2400/2400 [==============================] - 0s 70us/step - loss: 1.7663e-06 - acc: 1.0000 - val_loss: 0.0939 - val_acc: 0.9872
# Epoch 934/1000
# 2400/2400 [==============================] - 0s 55us/step - loss: 5.9546e-06 - acc: 1.0000 - val_loss: 0.0941 - val_acc: 0.9872
# Epoch 935/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 5.9215e-06 - acc: 1.0000 - val_loss: 0.0937 - val_acc: 0.9872
# Epoch 936/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 3.4870e-06 - acc: 1.0000 - val_loss: 0.0933 - val_acc: 0.9872
# Epoch 937/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 1.0665e-06 - acc: 1.0000 - val_loss: 0.0934 - val_acc: 0.9872
# Epoch 938/1000
# 2400/2400 [==============================] - 0s 84us/step - loss: 1.6016e-06 - acc: 1.0000 - val_loss: 0.0929 - val_acc: 0.9872
# Epoch 939/1000
# 2400/2400 [==============================] - 0s 85us/step - loss: 6.7703e-06 - acc: 1.0000 - val_loss: 0.0928 - val_acc: 0.9878
# Epoch 940/1000
# 2400/2400 [==============================] - 0s 61us/step - loss: 1.5484e-06 - acc: 1.0000 - val_loss: 0.0930 - val_acc: 0.9878
# Epoch 941/1000
# 2400/2400 [==============================] - 0s 86us/step - loss: 2.1853e-06 - acc: 1.0000 - val_loss: 0.0930 - val_acc: 0.9872
# Epoch 942/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 2.3634e-06 - acc: 1.0000 - val_loss: 0.0934 - val_acc: 0.9872
# Epoch 943/1000
# 2400/2400 [==============================] - 0s 70us/step - loss: 2.1476e-06 - acc: 1.0000 - val_loss: 0.0934 - val_acc: 0.9872
# Epoch 944/1000
# 2400/2400 [==============================] - 0s 58us/step - loss: 1.1366e-05 - acc: 1.0000 - val_loss: 0.0985 - val_acc: 0.9861
# Epoch 945/1000
# 2400/2400 [==============================] - 0s 79us/step - loss: 2.4365e-06 - acc: 1.0000 - val_loss: 0.0985 - val_acc: 0.9861
# Epoch 946/1000
# 2400/2400 [==============================] - 0s 74us/step - loss: 3.1883e-06 - acc: 1.0000 - val_loss: 0.0978 - val_acc: 0.9872
# Epoch 947/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 2.4051e-06 - acc: 1.0000 - val_loss: 0.0978 - val_acc: 0.9872
# Epoch 948/1000
# 2400/2400 [==============================] - 0s 59us/step - loss: 1.2096e-06 - acc: 1.0000 - val_loss: 0.0976 - val_acc: 0.9872
# Epoch 949/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 3.4821e-06 - acc: 1.0000 - val_loss: 0.0983 - val_acc: 0.9872
# Epoch 950/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 1.1877e-06 - acc: 1.0000 - val_loss: 0.0979 - val_acc: 0.9872
# Epoch 951/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 1.9334e-05 - acc: 1.0000 - val_loss: 0.0956 - val_acc: 0.9861
# Epoch 952/1000
# 2400/2400 [==============================] - 0s 58us/step - loss: 4.5064e-06 - acc: 1.0000 - val_loss: 0.0961 - val_acc: 0.9867
# Epoch 953/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 3.9825e-06 - acc: 1.0000 - val_loss: 0.0962 - val_acc: 0.9872
# Epoch 954/1000
# 2400/2400 [==============================] - 0s 70us/step - loss: 4.0138e-06 - acc: 1.0000 - val_loss: 0.0955 - val_acc: 0.9872
# Epoch 955/1000
# 2400/2400 [==============================] - 0s 78us/step - loss: 2.7073e-06 - acc: 1.0000 - val_loss: 0.0955 - val_acc: 0.9872
# Epoch 956/1000
# 2400/2400 [==============================] - 0s 60us/step - loss: 1.9100e-06 - acc: 1.0000 - val_loss: 0.0954 - val_acc: 0.9872
# Epoch 957/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 1.3269e-06 - acc: 1.0000 - val_loss: 0.0952 - val_acc: 0.9872
# Epoch 958/1000
# 2400/2400 [==============================] - 0s 85us/step - loss: 1.9495e-06 - acc: 1.0000 - val_loss: 0.0952 - val_acc: 0.9878
# Epoch 959/1000
# 2400/2400 [==============================] - 0s 75us/step - loss: 5.1957e-06 - acc: 1.0000 - val_loss: 0.0959 - val_acc: 0.9878
# Epoch 960/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 1.4442e-06 - acc: 1.0000 - val_loss: 0.0958 - val_acc: 0.9878
# Epoch 961/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 1.5998e-05 - acc: 1.0000 - val_loss: 0.0960 - val_acc: 0.9878
# Epoch 962/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 3.1317e-06 - acc: 1.0000 - val_loss: 0.0965 - val_acc: 0.9872
# Epoch 963/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 2.6441e-06 - acc: 1.0000 - val_loss: 0.0965 - val_acc: 0.9872
# Epoch 964/1000
# 2400/2400 [==============================] - 0s 60us/step - loss: 1.8546e-06 - acc: 1.0000 - val_loss: 0.0962 - val_acc: 0.9872
# Epoch 965/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 1.7004e-06 - acc: 1.0000 - val_loss: 0.0960 - val_acc: 0.9872
# Epoch 966/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 9.3960e-06 - acc: 1.0000 - val_loss: 0.0934 - val_acc: 0.9883
# Epoch 967/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 2.2112e-06 - acc: 1.0000 - val_loss: 0.0931 - val_acc: 0.9883
# Epoch 968/1000
# 2400/2400 [==============================] - 0s 74us/step - loss: 3.4345e-06 - acc: 1.0000 - val_loss: 0.0928 - val_acc: 0.9883
# Epoch 969/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 9.0555e-07 - acc: 1.0000 - val_loss: 0.0928 - val_acc: 0.9883
# Epoch 970/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 2.1859e-06 - acc: 1.0000 - val_loss: 0.0929 - val_acc: 0.9878
# Epoch 971/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 3.9353e-06 - acc: 1.0000 - val_loss: 0.0931 - val_acc: 0.9878
# Epoch 972/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 1.6635e-06 - acc: 1.0000 - val_loss: 0.0933 - val_acc: 0.9878
# Epoch 973/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 3.9493e-06 - acc: 1.0000 - val_loss: 0.0921 - val_acc: 0.9878
# Epoch 974/1000
# 2400/2400 [==============================] - 0s 67us/step - loss: 3.2146e-06 - acc: 1.0000 - val_loss: 0.0931 - val_acc: 0.9878
# Epoch 975/1000
# 2400/2400 [==============================] - 0s 80us/step - loss: 1.4851e-06 - acc: 1.0000 - val_loss: 0.0929 - val_acc: 0.9878
# Epoch 976/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 6.3821e-06 - acc: 1.0000 - val_loss: 0.0946 - val_acc: 0.9878
# Epoch 977/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 5.3080e-06 - acc: 1.0000 - val_loss: 0.0962 - val_acc: 0.9878
# Epoch 978/1000
# 2400/2400 [==============================] - 0s 78us/step - loss: 5.2178e-06 - acc: 1.0000 - val_loss: 0.0968 - val_acc: 0.9878
# Epoch 979/1000
# 2400/2400 [==============================] - 0s 66us/step - loss: 2.9762e-05 - acc: 1.0000 - val_loss: 0.1071 - val_acc: 0.9867
# Epoch 980/1000
# 2400/2400 [==============================] - 0s 74us/step - loss: 7.2585e-06 - acc: 1.0000 - val_loss: 0.1053 - val_acc: 0.9867
# Epoch 981/1000
# 2400/2400 [==============================] - 0s 75us/step - loss: 4.5645e-06 - acc: 1.0000 - val_loss: 0.1045 - val_acc: 0.9872
# Epoch 982/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 3.1472e-05 - acc: 1.0000 - val_loss: 0.1028 - val_acc: 0.9861
# Epoch 983/1000
# 2400/2400 [==============================] - 0s 63us/step - loss: 6.6309e-06 - acc: 1.0000 - val_loss: 0.1025 - val_acc: 0.9861
# Epoch 984/1000
# 2400/2400 [==============================] - 0s 86us/step - loss: 3.9896e-06 - acc: 1.0000 - val_loss: 0.1019 - val_acc: 0.9861
# Epoch 985/1000
# 2400/2400 [==============================] - 0s 68us/step - loss: 3.1773e-06 - acc: 1.0000 - val_loss: 0.1019 - val_acc: 0.9861
# Epoch 986/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 4.4445e-06 - acc: 1.0000 - val_loss: 0.1019 - val_acc: 0.9861
# Epoch 987/1000
# 2400/2400 [==============================] - 0s 69us/step - loss: 8.4630e-06 - acc: 1.0000 - val_loss: 0.1037 - val_acc: 0.9867
# Epoch 988/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 2.4186e-06 - acc: 1.0000 - val_loss: 0.1033 - val_acc: 0.9867
# Epoch 989/1000
# 2400/2400 [==============================] - 0s 70us/step - loss: 5.1574e-06 - acc: 1.0000 - val_loss: 0.1029 - val_acc: 0.9867
# Epoch 990/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 2.9530e-06 - acc: 1.0000 - val_loss: 0.1018 - val_acc: 0.9867
# Epoch 991/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 1.7118e-05 - acc: 1.0000 - val_loss: 0.0969 - val_acc: 0.9861
# Epoch 992/1000
# 2400/2400 [==============================] - 0s 76us/step - loss: 2.8944e-06 - acc: 1.0000 - val_loss: 0.0965 - val_acc: 0.9867
# Epoch 993/1000
# 2400/2400 [==============================] - 0s 71us/step - loss: 3.8356e-06 - acc: 1.0000 - val_loss: 0.0964 - val_acc: 0.9867
# Epoch 994/1000
# 2400/2400 [==============================] - 0s 73us/step - loss: 2.2944e-06 - acc: 1.0000 - val_loss: 0.0964 - val_acc: 0.9867
# Epoch 995/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 1.0249e-05 - acc: 1.0000 - val_loss: 0.0982 - val_acc: 0.9861
# Epoch 996/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 3.4457e-06 - acc: 1.0000 - val_loss: 0.0977 - val_acc: 0.9861
# Epoch 997/1000
# 2400/2400 [==============================] - 0s 72us/step - loss: 1.9081e-06 - acc: 1.0000 - val_loss: 0.0975 - val_acc: 0.9861
# Epoch 998/1000
# 2400/2400 [==============================] - 0s 82us/step - loss: 1.5898e-06 - acc: 1.0000 - val_loss: 0.0973 - val_acc: 0.9861
# Epoch 999/1000
# 2400/2400 [==============================] - 0s 61us/step - loss: 4.4484e-06 - acc: 1.0000 - val_loss: 0.0979 - val_acc: 0.9861
# Epoch 1000/1000
# 2400/2400 [==============================] - 0s 64us/step - loss: 3.0132e-06 - acc: 1.0000 - val_loss: 0.0970 - val_acc: 0.9861
# Test loss: 0.08533223435883769
# Test accuracy: 0.9866666666666667

# %%
def write_output(filename, shape, size):
    result = []
    for i in range(len(shape)):
        tc = shape[i].reshape(1, img_rows, img_cols, 1)
        output = get_layer_output([tc])
        output = np.array(output).reshape(size)
        result.append(output)
    np.save(filename, result)

# %%
circle = []
circle_filename = []
square = []
square_filename = []
triangle = []
triangle_filename = []
horizontal = []
horizontal_filename = []
vertical = []
vertical_filename = []
diagonal = []
diagonal_filename = []

# %%
for i in range(len(y_test1)):
    if y_test1[i] == 0:
        circle.append(x_test[i])
        circle_filename.append(test_labels_with_num[i])
    elif y_test1[i] == 1:
        square.append(x_test[i])
        square_filename.append(test_labels_with_num[i])
    elif y_test1[i] == 2:
        triangle.append(x_test[i])
        triangle_filename.append(test_labels_with_num[i])
    elif y_test1[i] == 3:
        horizontal.append(x_test[i])
        horizontal_filename.append(test_labels_with_num[i])
    elif y_test1[i] == 4:
        vertical.append(x_test[i])
        vertical_filename.append(test_labels_with_num[i])
    else:
        diagonal.append(x_test[i])
        diagonal_filename.append(test_labels_with_num[i])

# %%
get_layer_output = K.function([model.layers[0].input], [model.layers[15].output])

# %%
output_size = 64
write_output("./2nd_result/circle_output", circle, output_size)
write_output("./2nd_result/square_output", square, output_size)
write_output("./2nd_result/triangle_output", triangle, output_size)
write_output("./2nd_result/horizontal_output", horizontal, output_size)
write_output("./2nd_result/vertical_output", vertical, output_size)
write_output("./2nd_result/diagonal_output", diagonal, output_size)

# %%
total_filename = circle_filename+ square_filename + triangle_filename + horizontal_filename + vertical_filename+diagonal_filename

# %%
def getMaxMin(shape):
    mmax = -1000
    mmin = 1000
    for i in range(len(shape)):
        max = -1000
        min = 1000
        for j in range(len(shape[i])):
            if max < shape[i][j]:
                max = shape[i][j]
            if min > shape[i][j]:
                min = shape[i][j]
        if mmax < max:
            mmax = max
        if mmin > min:
            mmin = min
    return mmax, mmin

# %%
circle = np.load("./2nd_result/circle_output.npy")
square = np.load("./2nd_result/square_output.npy")
triangle = np.load("./2nd_result/triangle_output.npy")
horizontal = np.load("./2nd_result/horizontal_output.npy")
vertical = np.load("./2nd_result/vertical_output.npy")
diagonal = np.load("./2nd_result/diagonal_output.npy")

# %%
print("circle",getMaxMin(circle))
print("square",getMaxMin(square))
print("triangle",getMaxMin(triangle))
print("horizontal",getMaxMin(horizontal))
print("vertical",getMaxMin(vertical))
print("diagonal",getMaxMin(diagonal))
# Out:
# circle (25.42458, 0.0)
# square (38.14656, 0.0)
# triangle (38.27667, 0.0)
# horizontal (25.746904, 0.0)
# vertical (25.73626, 0.0)
# diagonal (39.26566, 0.0)

# %%
rand_index = random.randint(0, 100)
one = np.vstack([circle, square])
two = np.vstack([triangle, horizontal])
thr = np.vstack([vertical, diagonal])
total = np.vstack([one, two])
total = np.vstack([total, thr])

# %%
circle_dist = []
square_dist = []
triangle_dist = []
hor_dist = []
ver_dist = []
dia_dist = []

for line in total:
    circle_dist.append(distance.euclidean(circle[rand_index], line))
    square_dist.append(distance.euclidean(square[rand_index], line))
    triangle_dist.append(distance.euclidean(triangle[rand_index], line))
    hor_dist.append(distance.euclidean(horizontal[rand_index], line))
    ver_dist.append(distance.euclidean(vertical[rand_index], line))
    dia_dist.append(distance.euclidean(diagonal[rand_index], line))

# %%
ordered_circle_dist = np.array(circle_dist).argsort()
#print(ordered_circle_dist)
ordered_square_dist = np.array(square_dist).argsort()
#print(ordered_square_dist)
ordered_triangle_dist = np.array(triangle_dist).argsort()
#print(ordered_triangle_dist)
ordered_hor_dist = np.array(hor_dist).argsort()
#print(ordered_hor_dist)
ordered_ver_dist = np.array(ver_dist).argsort()
#print(ordered_ver_dist)
ordered_dia_dist = np.array(dia_dist).argsort()
#print(ordered_dia_dist)

# %%
def getCompareImages(shape, ordered_shape_dist):
    
    path = './dataset/tests/'
    images = []
    for i in range(len(ordered_shape_dist)):
        images.append(path + total_filename[ordered_shape_dist[i]] + ".png")
    
    names = []
    unit = 30
    
    for i in range(0, int(len(ordered_shape_dist)/unit)):
        imgs = [PIL.Image.open(i).convert('L') for i in images[i*unit:unit*(i+1)]]
        min_shape = sorted( [(np.sum(i.size), i.size ) for i in imgs])[0][1]
        imgs_comb = np.hstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )
        imgs_comb = PIL.Image.fromarray(imgs_comb)
        filename = "./2nd_result/test_"+ shape + str(i) + ".jpg"
        names.append(filename)
        imgs_comb.save(filename)

    imgs = [PIL.Image.open(i).convert('L') for i in names]
    min_shape = sorted( [(np.sum(i.size), i.size ) for i in imgs])[0][1]
    imgs_comb = np.vstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )
    imgs_comb = PIL.Image.fromarray( imgs_comb)
    imgs_comb.save( './2nd_result/' + shape+ '.jpg' )

    display(Image(path+total_filename[ordered_shape_dist[0]]+".png"))
    display(Image('./2nd_result/'+shape+'.jpg' ))

# %%
getCompareImages("circle", ordered_circle_dist)
getCompareImages("square", ordered_square_dist)
getCompareImages("triangle", ordered_triangle_dist)
getCompareImages("horizontal", ordered_hor_dist)
getCompareImages("vertical", ordered_ver_dist)
getCompareImages("diagonal", ordered_dia_dist)
# Out:
# /home/minji/.conda/envs/tensor/lib/python3.6/site-packages/ipykernel_launcher.py:14: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#
# /home/minji/.conda/envs/tensor/lib/python3.6/site-packages/ipykernel_launcher.py:22: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.

# %%
def getCountTop(total, ordered_shape_dist, shape):
    count = [0, 0, 0, 0, 0, 0]
    for i in range(0, total):
        for j in range(0, len(shape)):
            if(total_filename[ordered_shape_dist[i]].find(shape[j]) != -1):
                count[j] = count[j] + 1
                break
    return count

# %%
topNumber = 100
shape_distribution = []
shape_distribution.append(getCountTop(topNumber, ordered_circle_dist, label))
shape_distribution.append(getCountTop(topNumber, ordered_square_dist, label))
shape_distribution.append(getCountTop(topNumber, ordered_triangle_dist, label))
shape_distribution.append(getCountTop(topNumber, ordered_hor_dist, label))
shape_distribution.append(getCountTop(topNumber, ordered_ver_dist, label))
shape_distribution.append(getCountTop(topNumber, ordered_dia_dist, label))


for i in range(0, len(label)):
    print(label[i], "distribution :", shape_distribution[i])
    for j in range(len(shape_distribution)):
        print("\t", label[j], shape_distribution[i][j]/topNumber*100, "%")
    print()
# Out:
# circle distribution : [100, 0, 0, 0, 0, 0]
# 	 circle 100.0 %
# 	 square 0.0 %
# 	 triangle 0.0 %
# 	 horizontal 0.0 %
# 	 vertical 0.0 %
# 	 diagonal 0.0 %
#
# square distribution : [0, 100, 0, 0, 0, 0]
# 	 circle 0.0 %
# 	 square 100.0 %
# 	 triangle 0.0 %
# 	 horizontal 0.0 %
# 	 vertical 0.0 %
# 	 diagonal 0.0 %
#
# triangle distribution : [0, 0, 100, 0, 0, 0]
# 	 circle 0.0 %
# 	 square 0.0 %
# 	 triangle 100.0 %
# 	 horizontal 0.0 %
# 	 vertical 0.0 %
# 	 diagonal 0.0 %
#
# horizontal distribution : [0, 0, 0, 100, 0, 0]
# 	 circle 0.0 %
# 	 square 0.0 %
# 	 triangle 0.0 %
# 	 horizontal 100.0 %
# 	 vertical 0.0 %
# 	 diagonal 0.0 %
#
# vertical distribution : [0, 0, 0, 0, 100, 0]
# 	 circle 0.0 %
# 	 square 0.0 %
# 	 triangle 0.0 %
# 	 horizontal 0.0 %
# 	 vertical 100.0 %
# 	 diagonal 0.0 %
#
# diagonal distribution : [0, 0, 1, 0, 0, 99]
# 	 circle 0.0 %
# 	 square 0.0 %
# 	 triangle 1.0 %
# 	 horizontal 0.0 %
# 	 vertical 0.0 %
# 	 diagonal 99.0 %
